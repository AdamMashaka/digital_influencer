# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_json('/kaggle/input/synthetic-influencer-backstory/influencer_data.jsonl', lines=True)

# %%
# Basic information about the dataset
print("🔍 Basic Information of Dataset 🔍")
print(df.info())
# Out:
# 🔍 Basic Information of Dataset 🔍
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32890 entries, 0 to 32889
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32890 non-null  object
#  1   Age                32890 non-null  int64
#  2   Sex                32890 non-null  object
#  3   Country of Origin  32890 non-null  object
#  4   State or Province  32890 non-null  object
#  5   Education Level    32890 non-null  object
#  6   MBTI Personality   32890 non-null  object
#  7   Lifestyle          32890 non-null  object
#  8   Backstory          32890 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.3+ MB
# None

# %%
# Descriptive statistics of the dataset
print("\n📊 Descriptive Statistics 📊")
print(df.describe())
# Out:
# 📊 Descriptive Statistics 📊
#                 Age
# count  32890.000000
# mean      24.344482
# std        4.825563
# min       18.000000
# 25%       21.000000
# 50%       23.000000
# 75%       27.000000
# max       51.000000

# %%
# Distribution of Age
plt.figure(figsize=(8, 4))
sns.histplot(df['Age'], kde=True, color='skyblue')
plt.title('🎂 Distribution of Age 🎂')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 127874 (\N{BIRTHDAY CAKE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Gender count
plt.figure(figsize=(6, 4))
sns.countplot(x='Sex', data=df, palette='pastel')
plt.title('🚻 Sex Distribution 🚻')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128699 (\N{RESTROOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Lifestyle distribution
plt.figure(figsize=(12, 6))
sns.countplot(x='Lifestyle', data=df, palette='Set2')
plt.title('💃 Lifestyle Distribution 💃')
plt.xlabel('Lifestyle')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128131 (\N{DANCER}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
print("EDA script completed.")
# Out:
# EDA script completed.
